# %% [markdown]
# # Nested catalogs

# %% [markdown]
# We have a nested catalog pointing to the current esm-vfc-catalogs.

# %%
# !head -n13 esm-vfc-catalog.yaml
# !echo ...
# Out:
# sources:
#   FESOM2_PI_MESH:
#     args:
#       path: 'https://esm-vfc.github.io/esm-vfc-catalogs/catalogs/FESOM2_PI_MESH.yaml'
#     description: ''
#     driver: intake.catalog.local.YAMLFileCatalog
#     metadata: {}
#   METEOR_cruises:
#     args:
#       path: 'https://esm-vfc.github.io/esm-vfc-catalogs/catalogs/METEOR_cruises.yaml'
#     description: ''
#     driver: intake.catalog.local.YAMLFileCatalog
#     metadata: {}
# ...

# %% [markdown]
# # Parameters

# %%
#parameters
data_path = "esm_vfc_cata/"

# %% [markdown]
# ## Let's open it

# %%
import intake

# %%
cat = intake.open_catalog("esm-vfc-catalog.yaml")
list(cat)
# Out:
# ['FESOM2_PI_MESH',
#  'METEOR_cruises',
#  'MOSAIC',
#  'NEMO_GYRE_Test',
#  'NEMO_ORCA05_FOCI_Test_Full',
#  'NEMO_ORCA05_FOCI_Test_Minimal',
#  'NEMO_ORCA05_Test']

# %% [markdown]
# ## And fetch some data

# %%
import os
from pathlib import Path
import logging

from esmvfc_cattools import download_zenodo_files_for_entry

# %%
os.environ["ESM_VFC_DATA_DIR"] = str(Path(data_path).resolve())

# %%
logging.basicConfig(level=logging.DEBUG)

# %%
list(map(download_zenodo_files_for_entry, [cat.FESOM2_PI_MESH[name] for name in cat.FESOM2_PI_MESH]));
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): esm-vfc.github.io:443
# DEBUG:urllib3.connectionpool:https://esm-vfc.github.io:443 "HEAD /esm-vfc-catalogs/catalogs/FESOM2_PI_MESH.yaml HTTP/1.1" 200 0
# DEBUG:urllib3.connectionpool:https://esm-vfc.github.io:443 "GET /esm-vfc-catalogs/catalogs/FESOM2_PI_MESH.yaml HTTP/1.1" 200 1586
# DEBUG:fsspec:<File-like object HTTPFileSystem, https://esm-vfc.github.io/esm-vfc-catalogs/catalogs/FESOM2_PI_MESH.yaml> read: 0 - 1586
# DEBUG:root:will download record 3865567
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): zenodo.org:443
# DEBUG:urllib3.connectionpool:https://zenodo.org:443 "GET /api/records/3865567 HTTP/1.1" 200 None
# DEBUG:root:got status code 200
# DEBUG:root:will download https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/a_ice.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/a_ice.fesom.1948.nc
# DEBUG:root:download of https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/a_ice.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/a_ice.fesom.1948.nc done
# DEBUG:root:checksum md5:fd91d329b637be5a1d95e7fca8e19954 for ../esm_vfc_cata/FESOM2_PI_MESH/a_ice.fesom.1948.nc matches.
# DEBUG:root:will download https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/Av.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/Av.fesom.1948.nc
# DEBUG:root:download of https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/Av.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/Av.fesom.1948.nc done
# DEBUG:root:checksum md5:008f40a425030d78cc7de2b2ecec12be for ../esm_vfc_cata/FESOM2_PI_MESH/Av.fesom.1948.nc matches.
# DEBUG:root:will download https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/Kv.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/Kv.fesom.1948.nc
# DEBUG:root:download of https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/Kv.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/Kv.fesom.1948.nc done
# DEBUG:root:checksum md5:8fb21f1ea2ee1d8df38f7e8c038910a6 for ../esm_vfc_cata/FESOM2_PI_MESH/Kv.fesom.1948.nc matches.
# DEBUG:root:will download https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/m_ice.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/m_ice.fesom.1948.nc
# DEBUG:root:download of https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/m_ice.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/m_ice.fesom.1948.nc done
# DEBUG:root:checksum md5:1af4df6fa123f1371ceddf864df03d16 for ../esm_vfc_cata/FESOM2_PI_MESH/m_ice.fesom.1948.nc matches.
# DEBUG:root:will download https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/MLD1.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/MLD1.fesom.1948.nc
# DEBUG:root:download of https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/MLD1.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/MLD1.fesom.1948.nc done
# DEBUG:root:checksum md5:74d76ea817f668f28c52518b1a3726c3 for ../esm_vfc_cata/FESOM2_PI_MESH/MLD1.fesom.1948.nc matches.
# DEBUG:root:will download https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/salt.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/salt.fesom.1948.nc
# DEBUG:root:download of https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/salt.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/salt.fesom.1948.nc done
# DEBUG:root:checksum md5:210ee266b422a86405491bffa49e4125 for ../esm_vfc_cata/FESOM2_PI_MESH/salt.fesom.1948.nc matches.
# DEBUG:root:will download https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/ssh.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/ssh.fesom.1948.nc
# DEBUG:root:download of https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/ssh.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/ssh.fesom.1948.nc done
# DEBUG:root:checksum md5:9f721e3e83d503a19a011f01d45aa6d0 for ../esm_vfc_cata/FESOM2_PI_MESH/ssh.fesom.1948.nc matches.
# DEBUG:root:will download https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/sst.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/sst.fesom.1948.nc
# DEBUG:root:download of https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/sst.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/sst.fesom.1948.nc done
# DEBUG:root:checksum md5:368e9b9ec50f88c0f82817d3d6954cff for ../esm_vfc_cata/FESOM2_PI_MESH/sst.fesom.1948.nc matches.
# DEBUG:root:will download https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/temp.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/temp.fesom.1948.nc
# DEBUG:root:download of https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/temp.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/temp.fesom.1948.nc done
# DEBUG:root:checksum md5:006451ca186aec42cc6a26403e894a84 for ../esm_vfc_cata/FESOM2_PI_MESH/temp.fesom.1948.nc matches.
# DEBUG:root:will download https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/u.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/u.fesom.1948.nc
# DEBUG:root:download of https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/u.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/u.fesom.1948.nc done
# DEBUG:root:checksum md5:afd5fd1592bb013a756135ff999bf2d1 for ../esm_vfc_cata/FESOM2_PI_MESH/u.fesom.1948.nc matches.
# DEBUG:root:will download https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/uice.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/uice.fesom.1948.nc
# DEBUG:root:download of https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/uice.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/uice.fesom.1948.nc done
# DEBUG:root:checksum md5:a3579a96f753ff001723a90841944293 for ../esm_vfc_cata/FESOM2_PI_MESH/uice.fesom.1948.nc matches.
# DEBUG:root:will download https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/unod.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/unod.fesom.1948.nc
# DEBUG:root:download of https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/unod.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/unod.fesom.1948.nc done
# DEBUG:root:checksum md5:d55f8f5791241d7755696c34e336ea7f for ../esm_vfc_cata/FESOM2_PI_MESH/unod.fesom.1948.nc matches.
# DEBUG:root:will download https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/v.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/v.fesom.1948.nc
# DEBUG:root:download of https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/v.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/v.fesom.1948.nc done
# DEBUG:root:checksum md5:f36dfed88d70228e3123347e5935f83c for ../esm_vfc_cata/FESOM2_PI_MESH/v.fesom.1948.nc matches.
# DEBUG:root:will download https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/vice.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/vice.fesom.1948.nc
# DEBUG:root:download of https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/vice.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/vice.fesom.1948.nc done
# DEBUG:root:checksum md5:7b558dea947402af73b449659a7f8b66 for ../esm_vfc_cata/FESOM2_PI_MESH/vice.fesom.1948.nc matches.
# DEBUG:root:will download https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/vnod.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/vnod.fesom.1948.nc
# DEBUG:root:download of https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/vnod.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/vnod.fesom.1948.nc done
# DEBUG:root:checksum md5:3b21a72e74e6b4a9e25209976a823e80 for ../esm_vfc_cata/FESOM2_PI_MESH/vnod.fesom.1948.nc matches.
# DEBUG:root:will download https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/w.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/w.fesom.1948.nc
# DEBUG:root:download of https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/w.fesom.1948.nc to ../esm_vfc_cata/FESOM2_PI_MESH/w.fesom.1948.nc done
# DEBUG:root:checksum md5:9bfa1657f1f0a16216f3ad7f2dac2778 for ../esm_vfc_cata/FESOM2_PI_MESH/w.fesom.1948.nc matches.
# DEBUG:root:will download record 3865567
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): zenodo.org:443
# DEBUG:urllib3.connectionpool:https://zenodo.org:443 "GET /api/records/3865567 HTTP/1.1" 200 None
# DEBUG:root:got status code 200
# DEBUG:root:will download https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/pi.zip to ../esm_vfc_cata/FESOM2_PI_MESH/pi.zip
# DEBUG:root:download of https://zenodo.org/api/files/21cd530d-24d2-46bb-94c5-dc0ba924b5a6/pi.zip to ../esm_vfc_cata/FESOM2_PI_MESH/pi.zip done
# DEBUG:root:checksum md5:529cb1b4937a2247d57a6060b105b98f for ../esm_vfc_cata/FESOM2_PI_MESH/pi.zip matches.
# DEBUG:root:will download record 3865567
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): zenodo.org:443
# DEBUG:urllib3.connectionpool:https://zenodo.org:443 "GET /api/records/3865567 HTTP/1.1" 200 None
# DEBUG:root:got status code 200
# DEBUG:root:will download record 3865567
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): zenodo.org:443
# DEBUG:urllib3.connectionpool:https://zenodo.org:443 "GET /api/records/3865567 HTTP/1.1" 200 None
# DEBUG:root:got status code 200

# %% [markdown]
# ## Then read the FESOM fields we just fetched

# %%
cat.FESOM2_PI_MESH.FESOM2_sample.to_dask()
# Out:
# DEBUG:urllib3.connectionpool:https://esm-vfc.github.io:443 "HEAD /esm-vfc-catalogs/catalogs/FESOM2_PI_MESH.yaml HTTP/1.1" 200 0
# DEBUG:urllib3.connectionpool:https://esm-vfc.github.io:443 "GET /esm-vfc-catalogs/catalogs/FESOM2_PI_MESH.yaml HTTP/1.1" 200 1586
# DEBUG:fsspec:<File-like object HTTPFileSystem, https://esm-vfc.github.io/esm-vfc-catalogs/catalogs/FESOM2_PI_MESH.yaml> read: 0 - 1586
# <xarray.Dataset>
# Dimensions:  (elem: 5839, nod2: 3140, nz: 48, nz1: 47, time: 12)
# Coordinates:
#   * time     (time) float64 2.678e+06 5.097e+06 ... 2.886e+07 3.154e+07
# Dimensions without coordinates: elem, nod2, nz, nz1
# Data variables:
#     Av       (time, elem, nz) float32 dask.array<chunksize=(12, 5839, 48), meta=np.ndarray>
#     Kv       (time, nod2, nz) float32 dask.array<chunksize=(12, 3140, 48), meta=np.ndarray>
#     MLD1     (time, nod2) float32 dask.array<chunksize=(12, 3140), meta=np.ndarray>
#     a_ice    (time, nod2) float32 dask.array<chunksize=(12, 3140), meta=np.ndarray>
#     m_ice    (time, nod2) float32 dask.array<chunksize=(12, 3140), meta=np.ndarray>
#     salt     (time, nod2, nz1) float32 dask.array<chunksize=(12, 3140, 47), meta=np.ndarray>
#     ssh      (time, nod2) float32 dask.array<chunksize=(12, 3140), meta=np.ndarray>
#     sst      (time, nod2) float32 dask.array<chunksize=(12, 3140), meta=np.ndarray>
#     temp     (time, nod2, nz1) float32 dask.array<chunksize=(12, 3140, 47), meta=np.ndarray>
#     u        (time, elem, nz1) float32 dask.array<chunksize=(12, 5839, 47), meta=np.ndarray>
#     uice     (time, nod2) float32 dask.array<chunksize=(12, 3140), meta=np.ndarray>
#     unod     (time, nod2, nz1) float64 dask.array<chunksize=(12, 3140, 47), meta=np.ndarray>
#     v        (time, elem, nz1) float32 dask.array<chunksize=(12, 5839, 47), meta=np.ndarray>
#     vice     (time, nod2) float32 dask.array<chunksize=(12, 3140), meta=np.ndarray>
#     vnod     (time, nod2, nz1) float64 dask.array<chunksize=(12, 3140, 47), meta=np.ndarray>
#     w        (time, nod2, nz) float32 dask.array<chunksize=(12, 3140, 48), meta=np.ndarray>
